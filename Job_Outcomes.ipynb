# %% [markdown]
# # College Graduate Job Outcomes

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# recent_grads = pd.read_csv('recent-grads.csv')
# print(recent_grads.iloc[0])
# print(recent_grads.head())
# print(recent_grads.tail())
# print(recent_grads.describe())

# %%
print(recent_grads.shape)
recent_grads = recent_grads.dropna()
# Out:
# (172, 21)

# %%
ax1 = recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter')
ax1.set_title('Sample_size vs. Median')

# %%
ax2 = recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate',
                       kind = 'scatter')

ax2.set_title('Sample_size vs. Unemployment_rate')

# %%
ax3 = recent_grads.plot(x = 'Full_time', y = 'Median', kind='scatter')
ax3.set_title('Full_time vs. Median')

# %%
ax4 = recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate',
                       kind = 'scatter')
ax4.set_title('ShareWomen vs. Unemployment_rate')

# %%
ax5 = recent_grads.plot(x='Men', y ='Median', kind='scatter')
ax5.set_title('Men vs. Median')

# %%
ax6 = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax6.set_title('Women vs. Median')

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist(bins = 15)

# %%
recent_grads['Employed'].hist(bins=25, range=(0,10000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,250000))

# %%
recent_grads['ShareWomen'].hist(bins=35)

# %%
recent_grads['Unemployment_rate'].hist(bins=25)

# %%
recent_grads['Men'].hist(bins=15, range=(0,200000))

# %%
recent_grads['Women'].hist(bins=15, range=(0,200000))

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']])
scatter_matrix(recent_grads[['Sample_size', 'Median', 
                            'Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a1fc9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a1ac438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a1206d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a0eab00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a0a6ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a06dcf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa55a02aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa559ff5be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa559f84e80>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[163:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate')
